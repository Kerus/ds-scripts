# %% [markdown]
# # Фишка с выбросами
# В данных есть явные выбросы, которые сильно влияют на оцениваемую метрику ошибки
# В предыдущем ядре, мы вручную добавили бинарный признак, характеризующий строку данных как выброс или нет
# ## Шаг 1
# мы обучим модель на данных без выбросов и будем использовать ее прогноз как базовый
# ## Шаг 2
# обучим новую модель для предсказания, являются ли данные выбросом
# ## Шаг 3
# берем первые n (10к) наиболее вероятных выбросов из прогноза модели с шага 2 и заменяем ответы у этих card_id в прогнозе, полученном от модели без выбросов (из шага 1), на ответы нашей лучшей модели, которая обучалась на смешанных данных
#
# Ссылка на соревнование: https://www.kaggle.com/c/elo-merchant-category-recommendation

# %%
import numpy as np
import pandas as pd
import time
import lightgbm as lgb
from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.metrics import mean_squared_error
from sklearn.metrics import log_loss

# %%
# rmse
def rmse(y_true, y_pred):
    return np.sqrt(mean_squared_error(y_true, y_pred))

# %% [markdown]
# ## Step 1. Training model without outliers

# %%
# %%time
df_train = pd.read_csv('D:\Ellunium\elo/train_data_clean_16_02.csv')
df_test = pd.read_csv('D:\Ellunium\elo/test_data_clean_16_02.csv')
# Out:
# Wall time: 24.4 s

# %%
FEATS_EXCLUDED = ['first_active_month', 'target', 'card_id', 'outliers',
                  'hist_purchase_date_max', 'hist_purchase_date_min', 'hist_card_id_size',
                  'new_purchase_date_max', 'new_purchase_date_min', 'new_card_id_size',
                  'OOF_PRED', 'month_0','observation_date_x','observation_date_y']

df_train = df_train[df_train['outliers'] == 0]
target = df_train['target']
del df_train['target']
features = [c for c in df_train.columns if c not in FEATS_EXCLUDED]
categorical_feats = [c for c in features if 'feature_' in c]

# %%
# %%time
param = {'objective':'regression',
         'num_leaves': 31,
         'min_data_in_leaf': 25,
         'max_depth': 7,
         'learning_rate': 0.01,
         'lambda_l1':0.13,
         "boosting": "gbdt",
         "feature_fraction":0.85,
         'bagging_freq':8,
         "bagging_fraction": 0.9 ,
         "metric": 'rmse',
         "verbosity": -1,
         "random_state": 2333}

folds = StratifiedKFold(n_splits=11, shuffle=True, random_state=1245)
oof_lgb = np.zeros(len(df_train))
predictions_lgb = np.zeros(len(df_test))
feature_importance_df = pd.DataFrame()

for fold_, (trn_idx, val_idx) in enumerate(folds.split(df_train,df_train['outliers'].values)):
    print("fold {}".format(fold_))
    trn_data = lgb.Dataset(df_train.iloc[trn_idx][features], label=target.iloc[trn_idx])#, categorical_feature=categorical_feats)
    val_data = lgb.Dataset(df_train.iloc[val_idx][features], label=target.iloc[val_idx])#, categorical_feature=categorical_feats)

    num_round = 10000
    clf = lgb.train(param, trn_data, num_round, valid_sets = [trn_data, val_data], verbose_eval= 100, early_stopping_rounds = 200)
    oof_lgb[val_idx] = clf.predict(df_train.iloc[val_idx][features], num_iteration=clf.best_iteration)
    
    fold_importance_df = pd.DataFrame()
    fold_importance_df["Feature"] = features
    fold_importance_df["importance"] = clf.feature_importance()
    fold_importance_df["fold"] = fold_ + 1
    feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
    
    predictions_lgb += clf.predict(df_test[features], num_iteration=clf.best_iteration) / folds.n_splits

print("CV score: {:<8.5f}".format(mean_squared_error(oof_lgb, target)**0.5))
# Out:
# fold 0
# Training until validation scores don't improve for 200 rounds.
# [100]	training's rmse: 1.60934	valid_1's rmse: 1.60201
# [200]	training's rmse: 1.57868	valid_1's rmse: 1.57461
# [300]	training's rmse: 1.56401	valid_1's rmse: 1.56407
# [400]	training's rmse: 1.55456	valid_1's rmse: 1.55898
# [500]	training's rmse: 1.5474	valid_1's rmse: 1.55583
# [600]	training's rmse: 1.54136	valid_1's rmse: 1.55376
# [700]	training's rmse: 1.5359	valid_1's rmse: 1.55246
# [800]	training's rmse: 1.53098	valid_1's rmse: 1.55116
# [900]	training's rmse: 1.52655	valid_1's rmse: 1.55059
# [1000]	training's rmse: 1.52244	valid_1's rmse: 1.54971
# [1100]	training's rmse: 1.5186	valid_1's rmse: 1.54921
# [1200]	training's rmse: 1.51484	valid_1's rmse: 1.54904
# [1300]	training's rmse: 1.51115	valid_1's rmse: 1.54861
# [1400]	training's rmse: 1.50763	valid_1's rmse: 1.54828
# [1500]	training's rmse: 1.50425	valid_1's rmse: 1.54808
# [1600]	training's rmse: 1.50073	valid_1's rmse: 1.54781
# [1700]	training's rmse: 1.49736	valid_1's rmse: 1.54753
# [1800]	training's rmse: 1.49413	valid_1's rmse: 1.54737
# [1900]	training's rmse: 1.49077	valid_1's rmse: 1.54727
# [2000]	training's rmse: 1.48765	valid_1's rmse: 1.54699
# [2100]	training's rmse: 1.48442	valid_1's rmse: 1.54683
# [2200]	training's rmse: 1.48134	valid_1's rmse: 1.54682
# [2300]	training's rmse: 1.47835	valid_1's rmse: 1.54674
# [2400]	training's rmse: 1.4752	valid_1's rmse: 1.54643
# [2500]	training's rmse: 1.47227	valid_1's rmse: 1.54649
# [2600]	training's rmse: 1.46944	valid_1's rmse: 1.54645
# Early stopping, best iteration is:
# [2421]	training's rmse: 1.47463	valid_1's rmse: 1.54636
# fold 1
# Training until validation scores don't improve for 200 rounds.
# [100]	training's rmse: 1.60995	valid_1's rmse: 1.59551
# [200]	training's rmse: 1.57918	valid_1's rmse: 1.56961
# [300]	training's rmse: 1.56457	valid_1's rmse: 1.55888
# [400]	training's rmse: 1.55523	valid_1's rmse: 1.55305
# [500]	training's rmse: 1.54803	valid_1's rmse: 1.54954
# [600]	training's rmse: 1.5421	valid_1's rmse: 1.5472
# [700]	training's rmse: 1.53679	valid_1's rmse: 1.54564
# [800]	training's rmse: 1.53216	valid_1's rmse: 1.54473
# [900]	training's rmse: 1.52766	valid_1's rmse: 1.54395
# [1000]	training's rmse: 1.5235	valid_1's rmse: 1.54338
# [1100]	training's rmse: 1.51947	valid_1's rmse: 1.54266
# [1200]	training's rmse: 1.51573	valid_1's rmse: 1.5423
# [1300]	training's rmse: 1.51207	valid_1's rmse: 1.54205
# [1400]	training's rmse: 1.50846	valid_1's rmse: 1.54185
# [1500]	training's rmse: 1.50501	valid_1's rmse: 1.54145
# [1600]	training's rmse: 1.50147	valid_1's rmse: 1.54123
# [1700]	training's rmse: 1.4982	valid_1's rmse: 1.54117
# [1800]	training's rmse: 1.4949	valid_1's rmse: 1.54102
# [1900]	training's rmse: 1.49166	valid_1's rmse: 1.54084
# [2000]	training's rmse: 1.48849	valid_1's rmse: 1.54065
# [2100]	training's rmse: 1.48553	valid_1's rmse: 1.54069
# [2200]	training's rmse: 1.4825	valid_1's rmse: 1.54055
# [2300]	training's rmse: 1.47952	valid_1's rmse: 1.54037
# [2400]	training's rmse: 1.47649	valid_1's rmse: 1.5403
# [2500]	training's rmse: 1.47354	valid_1's rmse: 1.54028
# [2600]	training's rmse: 1.47048	valid_1's rmse: 1.54036
# [2700]	training's rmse: 1.46761	valid_1's rmse: 1.54024
# [2800]	training's rmse: 1.46469	valid_1's rmse: 1.54013
# [2900]	training's rmse: 1.46185	valid_1's rmse: 1.54017
# Early stopping, best iteration is:
# [2752]	training's rmse: 1.46606	valid_1's rmse: 1.54008
# fold 2
# Training until validation scores don't improve for 200 rounds.
# [100]	training's rmse: 1.60749	valid_1's rmse: 1.61964
# [200]	training's rmse: 1.57659	valid_1's rmse: 1.59336
# [300]	training's rmse: 1.56186	valid_1's rmse: 1.58349
# [400]	training's rmse: 1.5525	valid_1's rmse: 1.57902
# [500]	training's rmse: 1.54512	valid_1's rmse: 1.57604
# [600]	training's rmse: 1.53899	valid_1's rmse: 1.57434
# [700]	training's rmse: 1.53365	valid_1's rmse: 1.57324
# [800]	training's rmse: 1.52874	valid_1's rmse: 1.57259
# [900]	training's rmse: 1.52426	valid_1's rmse: 1.57223
# [1000]	training's rmse: 1.52018	valid_1's rmse: 1.57191
# [1100]	training's rmse: 1.51612	valid_1's rmse: 1.57183
# [1200]	training's rmse: 1.51231	valid_1's rmse: 1.57167
# [1300]	training's rmse: 1.50856	valid_1's rmse: 1.57159
# [1400]	training's rmse: 1.5051	valid_1's rmse: 1.57148
# [1500]	training's rmse: 1.50165	valid_1's rmse: 1.57149
# [1600]	training's rmse: 1.49812	valid_1's rmse: 1.57142
# [1700]	training's rmse: 1.49478	valid_1's rmse: 1.57133
# [1800]	training's rmse: 1.49145	valid_1's rmse: 1.57143
# [1900]	training's rmse: 1.48802	valid_1's rmse: 1.57123
# [2000]	training's rmse: 1.48487	valid_1's rmse: 1.5714
# Early stopping, best iteration is:
# [1899]	training's rmse: 1.48804	valid_1's rmse: 1.57123
# fold 3
# Training until validation scores don't improve for 200 rounds.
# [100]	training's rmse: 1.60702	valid_1's rmse: 1.62522
# [200]	training's rmse: 1.57601	valid_1's rmse: 1.59872
# [300]	training's rmse: 1.56139	valid_1's rmse: 1.58849
# [400]	training's rmse: 1.55199	valid_1's rmse: 1.5834
# [500]	training's rmse: 1.54484	valid_1's rmse: 1.58055
# [600]	training's rmse: 1.53888	valid_1's rmse: 1.57866
# [700]	training's rmse: 1.53362	valid_1's rmse: 1.57727
# [800]	training's rmse: 1.52875	valid_1's rmse: 1.57612
# [900]	training's rmse: 1.52448	valid_1's rmse: 1.57533
# [1000]	training's rmse: 1.52046	valid_1's rmse: 1.57497
# [1100]	training's rmse: 1.51649	valid_1's rmse: 1.57484
# [1200]	training's rmse: 1.5126	valid_1's rmse: 1.57453
# [1300]	training's rmse: 1.50899	valid_1's rmse: 1.57412
# [1400]	training's rmse: 1.5054	valid_1's rmse: 1.5738
# [1500]	training's rmse: 1.50203	valid_1's rmse: 1.5737
# [1600]	training's rmse: 1.49873	valid_1's rmse: 1.57376
# [1700]	training's rmse: 1.49554	valid_1's rmse: 1.57376
# [1800]	training's rmse: 1.49223	valid_1's rmse: 1.57348
# [1900]	training's rmse: 1.48886	valid_1's rmse: 1.57336
# [2000]	training's rmse: 1.48552	valid_1's rmse: 1.57336
# [2100]	training's rmse: 1.48226	valid_1's rmse: 1.57308
# [2200]	training's rmse: 1.47913	valid_1's rmse: 1.57295
# [2300]	training's rmse: 1.4762	valid_1's rmse: 1.57287
# [2400]	training's rmse: 1.47316	valid_1's rmse: 1.57293
# Early stopping, best iteration is:
# [2280]	training's rmse: 1.47683	valid_1's rmse: 1.57283
# fold 4
# Training until validation scores don't improve for 200 rounds.
# [100]	training's rmse: 1.60871	valid_1's rmse: 1.60691
# [200]	training's rmse: 1.57782	valid_1's rmse: 1.58275
# [300]	training's rmse: 1.56317	valid_1's rmse: 1.57344
# [400]	training's rmse: 1.55357	valid_1's rmse: 1.56885
# [500]	training's rmse: 1.54629	valid_1's rmse: 1.56616
# [600]	training's rmse: 1.54017	valid_1's rmse: 1.56415
# [700]	training's rmse: 1.53482	valid_1's rmse: 1.56291
# [800]	training's rmse: 1.52982	valid_1's rmse: 1.56189
# [900]	training's rmse: 1.52537	valid_1's rmse: 1.56149
# [1000]	training's rmse: 1.52106	valid_1's rmse: 1.56105
# [1100]	training's rmse: 1.51708	valid_1's rmse: 1.56085
# [1200]	training's rmse: 1.51322	valid_1's rmse: 1.56062
# [1300]	training's rmse: 1.50944	valid_1's rmse: 1.56037
# [1400]	training's rmse: 1.50579	valid_1's rmse: 1.56025
# [1500]	training's rmse: 1.5023	valid_1's rmse: 1.56018
# [1600]	training's rmse: 1.49901	valid_1's rmse: 1.56019
# [1700]	training's rmse: 1.49571	valid_1's rmse: 1.56022
# [1800]	training's rmse: 1.49224	valid_1's rmse: 1.56028
# Early stopping, best iteration is:
# [1637]	training's rmse: 1.49777	valid_1's rmse: 1.56009
# fold 5
# Training until validation scores don't improve for 200 rounds.
# [100]	training's rmse: 1.60418	valid_1's rmse: 1.65183
# [200]	training's rmse: 1.57355	valid_1's rmse: 1.62585
# [300]	training's rmse: 1.55907	valid_1's rmse: 1.61516
# [400]	training's rmse: 1.54985	valid_1's rmse: 1.60975
# [500]	training's rmse: 1.54275	valid_1's rmse: 1.60614
# [600]	training's rmse: 1.53677	valid_1's rmse: 1.60362
# [700]	training's rmse: 1.53143	valid_1's rmse: 1.60215
# [800]	training's rmse: 1.52667	valid_1's rmse: 1.60083
# [900]	training's rmse: 1.52221	valid_1's rmse: 1.59985
# [1000]	training's rmse: 1.5181	valid_1's rmse: 1.59922
# [1100]	training's rmse: 1.51411	valid_1's rmse: 1.59885
# [1200]	training's rmse: 1.51012	valid_1's rmse: 1.59835
# [1300]	training's rmse: 1.50648	valid_1's rmse: 1.59804
# [1400]	training's rmse: 1.50294	valid_1's rmse: 1.59792
# [1500]	training's rmse: 1.49942	valid_1's rmse: 1.59758
# [1600]	training's rmse: 1.49592	valid_1's rmse: 1.59747
# [1700]	training's rmse: 1.49258	valid_1's rmse: 1.59724
# [1800]	training's rmse: 1.48917	valid_1's rmse: 1.59725
# [1900]	training's rmse: 1.48607	valid_1's rmse: 1.59711
# [2000]	training's rmse: 1.48284	valid_1's rmse: 1.597
# [2100]	training's rmse: 1.4796	valid_1's rmse: 1.59679
# [2200]	training's rmse: 1.47652	valid_1's rmse: 1.59665
# [2300]	training's rmse: 1.47356	valid_1's rmse: 1.59666
# [2400]	training's rmse: 1.47061	valid_1's rmse: 1.59663
# [2500]	training's rmse: 1.46753	valid_1's rmse: 1.59653
# [2600]	training's rmse: 1.46448	valid_1's rmse: 1.59656
# [2700]	training's rmse: 1.46166	valid_1's rmse: 1.59653
# [2800]	training's rmse: 1.45874	valid_1's rmse: 1.59644
# [2900]	training's rmse: 1.45592	valid_1's rmse: 1.59623
# [3000]	training's rmse: 1.45302	valid_1's rmse: 1.59617
# [3100]	training's rmse: 1.45024	valid_1's rmse: 1.59642
# Early stopping, best iteration is:
# [2923]	training's rmse: 1.45525	valid_1's rmse: 1.5961
# fold 6
# Training until validation scores don't improve for 200 rounds.
# [100]	training's rmse: 1.60645	valid_1's rmse: 1.63226
# [200]	training's rmse: 1.57624	valid_1's rmse: 1.60282
# [300]	training's rmse: 1.56182	valid_1's rmse: 1.59073
# [400]	training's rmse: 1.5524	valid_1's rmse: 1.58483
# [500]	training's rmse: 1.54512	valid_1's rmse: 1.58079
# [600]	training's rmse: 1.53908	valid_1's rmse: 1.57802
# [700]	training's rmse: 1.53377	valid_1's rmse: 1.57632
# [800]	training's rmse: 1.52908	valid_1's rmse: 1.57521
# [900]	training's rmse: 1.52459	valid_1's rmse: 1.57441
# [1000]	training's rmse: 1.52047	valid_1's rmse: 1.57375
# [1100]	training's rmse: 1.51647	valid_1's rmse: 1.5734
# [1200]	training's rmse: 1.51267	valid_1's rmse: 1.57309
# [1300]	training's rmse: 1.50909	valid_1's rmse: 1.57283
# [1400]	training's rmse: 1.50569	valid_1's rmse: 1.57257
# [1500]	training's rmse: 1.50205	valid_1's rmse: 1.57234
# [1600]	training's rmse: 1.49865	valid_1's rmse: 1.57212
# [1700]	training's rmse: 1.49524	valid_1's rmse: 1.57181
# [1800]	training's rmse: 1.49182	valid_1's rmse: 1.5717
# [1900]	training's rmse: 1.48859	valid_1's rmse: 1.57157
# [2000]	training's rmse: 1.48527	valid_1's rmse: 1.57145
# [2100]	training's rmse: 1.48199	valid_1's rmse: 1.57155
# [2200]	training's rmse: 1.47897	valid_1's rmse: 1.57156
# Early stopping, best iteration is:
# [2029]	training's rmse: 1.48437	valid_1's rmse: 1.57143
# fold 7
# Training until validation scores don't improve for 200 rounds.
# [100]	training's rmse: 1.60846	valid_1's rmse: 1.60811
# [200]	training's rmse: 1.57792	valid_1's rmse: 1.58127
# [300]	training's rmse: 1.56326	valid_1's rmse: 1.57053
# [400]	training's rmse: 1.5538	valid_1's rmse: 1.56525
# [500]	training's rmse: 1.54649	valid_1's rmse: 1.56183
# [600]	training's rmse: 1.54046	valid_1's rmse: 1.55972
# [700]	training's rmse: 1.53509	valid_1's rmse: 1.55832
# [800]	training's rmse: 1.53042	valid_1's rmse: 1.55752
# [900]	training's rmse: 1.52597	valid_1's rmse: 1.5569
# [1000]	training's rmse: 1.52186	valid_1's rmse: 1.55648
# [1100]	training's rmse: 1.51799	valid_1's rmse: 1.55614
# [1200]	training's rmse: 1.5141	valid_1's rmse: 1.55555
# [1300]	training's rmse: 1.51042	valid_1's rmse: 1.55528
# [1400]	training's rmse: 1.50692	valid_1's rmse: 1.55524
# [1500]	training's rmse: 1.50336	valid_1's rmse: 1.55517
# [1600]	training's rmse: 1.49978	valid_1's rmse: 1.55497
# [1700]	training's rmse: 1.49642	valid_1's rmse: 1.55473
# [1800]	training's rmse: 1.49285	valid_1's rmse: 1.55456
# [1900]	training's rmse: 1.48968	valid_1's rmse: 1.55455
# [2000]	training's rmse: 1.48632	valid_1's rmse: 1.55438
# [2100]	training's rmse: 1.48331	valid_1's rmse: 1.55424
# [2200]	training's rmse: 1.48026	valid_1's rmse: 1.55424
# [2300]	training's rmse: 1.47721	valid_1's rmse: 1.55437
# Early stopping, best iteration is:
# [2145]	training's rmse: 1.48192	valid_1's rmse: 1.5542
# fold 8
# Training until validation scores don't improve for 200 rounds.
# [100]	training's rmse: 1.61001	valid_1's rmse: 1.59416
# [200]	training's rmse: 1.57912	valid_1's rmse: 1.56818
# [300]	training's rmse: 1.56439	valid_1's rmse: 1.55789
# [400]	training's rmse: 1.55503	valid_1's rmse: 1.55268
# [500]	training's rmse: 1.54775	valid_1's rmse: 1.54957
# [600]	training's rmse: 1.54175	valid_1's rmse: 1.54763
# [700]	training's rmse: 1.53634	valid_1's rmse: 1.54635
# [800]	training's rmse: 1.5317	valid_1's rmse: 1.54532
# [900]	training's rmse: 1.52728	valid_1's rmse: 1.5449
# [1000]	training's rmse: 1.52308	valid_1's rmse: 1.54444
# [1100]	training's rmse: 1.51919	valid_1's rmse: 1.54412
# [1200]	training's rmse: 1.51551	valid_1's rmse: 1.54379
# [1300]	training's rmse: 1.51184	valid_1's rmse: 1.54364
# [1400]	training's rmse: 1.50819	valid_1's rmse: 1.54347
# [1500]	training's rmse: 1.50472	valid_1's rmse: 1.5431
# [1600]	training's rmse: 1.50142	valid_1's rmse: 1.54315
# [1700]	training's rmse: 1.49814	valid_1's rmse: 1.54312
# Early stopping, best iteration is:
# [1542]	training's rmse: 1.50329	valid_1's rmse: 1.54305
# fold 9
# Training until validation scores don't improve for 200 rounds.
# [100]	training's rmse: 1.60966	valid_1's rmse: 1.59786
# [200]	training's rmse: 1.57878	valid_1's rmse: 1.57115
# [300]	training's rmse: 1.56406	valid_1's rmse: 1.56049
# [400]	training's rmse: 1.55468	valid_1's rmse: 1.55535
# [500]	training's rmse: 1.54749	valid_1's rmse: 1.55198
# [600]	training's rmse: 1.54139	valid_1's rmse: 1.54992
# [700]	training's rmse: 1.53604	valid_1's rmse: 1.54852
# [800]	training's rmse: 1.53143	valid_1's rmse: 1.54774
# [900]	training's rmse: 1.52708	valid_1's rmse: 1.54715
# [1000]	training's rmse: 1.52288	valid_1's rmse: 1.54639
# [1100]	training's rmse: 1.51906	valid_1's rmse: 1.54609
# [1200]	training's rmse: 1.51539	valid_1's rmse: 1.54605
# [1300]	training's rmse: 1.51167	valid_1's rmse: 1.54592
# [1400]	training's rmse: 1.50792	valid_1's rmse: 1.54568
# [1500]	training's rmse: 1.50451	valid_1's rmse: 1.54548
# [1600]	training's rmse: 1.50114	valid_1's rmse: 1.54551
# [1700]	training's rmse: 1.49783	valid_1's rmse: 1.54536
# [1800]	training's rmse: 1.49452	valid_1's rmse: 1.54514
# [1900]	training's rmse: 1.4912	valid_1's rmse: 1.54486
# [2000]	training's rmse: 1.48802	valid_1's rmse: 1.54472
# [2100]	training's rmse: 1.48482	valid_1's rmse: 1.54471
# [2200]	training's rmse: 1.4816	valid_1's rmse: 1.54457
# [2300]	training's rmse: 1.47851	valid_1's rmse: 1.54454
# [2400]	training's rmse: 1.47532	valid_1's rmse: 1.54444
# [2500]	training's rmse: 1.47238	valid_1's rmse: 1.54434
# [2600]	training's rmse: 1.46932	valid_1's rmse: 1.54434
# [2700]	training's rmse: 1.46638	valid_1's rmse: 1.54425
# [2800]	training's rmse: 1.46336	valid_1's rmse: 1.54414
# [2900]	training's rmse: 1.46052	valid_1's rmse: 1.54427
# Early stopping, best iteration is:
# [2784]	training's rmse: 1.46387	valid_1's rmse: 1.54411
# fold 10
# Training until validation scores don't improve for 200 rounds.
# [100]	training's rmse: 1.60955	valid_1's rmse: 1.60081
# [200]	training's rmse: 1.57896	valid_1's rmse: 1.57242
# [300]	training's rmse: 1.56439	valid_1's rmse: 1.56096
# [400]	training's rmse: 1.55497	valid_1's rmse: 1.55487
# [500]	training's rmse: 1.54775	valid_1's rmse: 1.55131
# [600]	training's rmse: 1.54169	valid_1's rmse: 1.54892
# [700]	training's rmse: 1.53635	valid_1's rmse: 1.54751
# [800]	training's rmse: 1.53165	valid_1's rmse: 1.54648
# [900]	training's rmse: 1.52718	valid_1's rmse: 1.54545
# [1000]	training's rmse: 1.523	valid_1's rmse: 1.54506
# [1100]	training's rmse: 1.51909	valid_1's rmse: 1.54465
# [1200]	training's rmse: 1.51516	valid_1's rmse: 1.54421
# [1300]	training's rmse: 1.51161	valid_1's rmse: 1.54398
# [1400]	training's rmse: 1.50795	valid_1's rmse: 1.5438
# [1500]	training's rmse: 1.50434	valid_1's rmse: 1.54384
# [1600]	training's rmse: 1.50107	valid_1's rmse: 1.54369
# [1700]	training's rmse: 1.49781	valid_1's rmse: 1.54352
# [1800]	training's rmse: 1.49448	valid_1's rmse: 1.54349
# [1900]	training's rmse: 1.49133	valid_1's rmse: 1.54348
# [2000]	training's rmse: 1.48824	valid_1's rmse: 1.54349
# Early stopping, best iteration is:
# [1835]	training's rmse: 1.49341	valid_1's rmse: 1.54341
# CV score: 1.55853
# Wall time: 2h 1min 28s

# %%
#Cat boost
import catboost as cb

oof_cb = np.zeros(len(df_train))
predictions_cb = np.zeros(df_test.shape[0])

folds = StratifiedKFold(n_splits=5, shuffle=True, random_state=345)

for n_fold, (train_idx, valid_idx) in enumerate(folds.split(df_train[features], df_train['outliers'].values)):
    train_x, train_y = df_train[features].iloc[train_idx], target.iloc[train_idx]
    valid_x, valid_y = df_train[features].iloc[valid_idx], target.iloc[valid_idx]
    
    # CatBoost Regressor estimator
    model = cb.CatBoostRegressor(
        learning_rate = 0.03,
        iterations = 1000,
        eval_metric = 'RMSE',
        allow_writing_files = False,
        od_type = 'Iter',
        bagging_temperature = 0.2,
        depth = 10,
        od_wait = 20,
        silent = True
    )
    
    # Fit
    model.fit(
        train_x, train_y,
        eval_set=[(train_x, train_y), (valid_x, valid_y)],
        verbose=None,
        early_stopping_rounds=100
    )
    
    print("CB " + str(n_fold) + "-" * 50)
    
    oof_cb[valid_idx] = model.predict(valid_x)
    test_preds = model.predict(df_test[features])
    predictions_cb += test_preds / folds.n_splits
    print('Fold %2d RMSE : %.6f' % (n_fold + 1, rmse(valid_y, oof_cb[valid_idx])))

print('Cat Boost RMSE: {:<8.5f}'.format(rmse(oof_cb, target)))
# Out:
# CB 0--------------------------------------------------
# Fold  1 RMSE : 1.547999
# CB 1--------------------------------------------------
# Fold  2 RMSE : 1.557780
# CB 2--------------------------------------------------
# Fold  3 RMSE : 1.564711
# CB 3--------------------------------------------------
# Fold  4 RMSE : 1.568365
# CB 4--------------------------------------------------
# Fold  5 RMSE : 1.556924
# Cat Boost RMSE: 1.55917

# %%
# %%time
#XGB
import xgboost as xgb

xgb_params = {'eta': 0.005, 'max_depth': 9, 'subsample': 0.8, 'colsample_bytree': 0.8, 
          'objective': 'reg:linear', 'eval_metric': 'rmse', 'silent': True}

oof_xgb = np.zeros(len(df_train))
predictions_xgb = np.zeros(len(df_test))

folds = StratifiedKFold(n_splits=5, shuffle=True, random_state=345)

for n_fold, (trn_idx, val_idx) in enumerate(folds.split(df_train[features], df_train['outliers'].values)):
    trn_data = xgb.DMatrix(data=df_train.iloc[trn_idx][features], label=target.iloc[trn_idx])
    val_data = xgb.DMatrix(data=df_train.iloc[val_idx][features], label=target.iloc[val_idx])
    watchlist = [(trn_data, 'train'), (val_data, 'valid')]
    print("XGB " + str(n_fold) + "-" * 50)
    num_round = 10000
    xgb_model = xgb.train(xgb_params, trn_data, num_round, watchlist, early_stopping_rounds=50, verbose_eval=1000)
    oof_xgb[val_idx] = xgb_model.predict(xgb.DMatrix(df_train.iloc[val_idx][features]), ntree_limit=xgb_model.best_ntree_limit+50)

    predictions_xgb += xgb_model.predict(xgb.DMatrix(df_test[features]), ntree_limit=xgb_model.best_ntree_limit+50) / folds.n_splits
    print('Fold %2d RMSE : %.6f' % (n_fold + 1, rmse(target.iloc[val_idx], oof_xgb[val_idx])))
    
print(np.sqrt(mean_squared_error(oof_xgb, target)))
# Out:
# XGB 0--------------------------------------------------
# [0]	train-rmse:1.80037	valid-rmse:1.77758
# Multiple eval metrics have been passed: 'valid-rmse' will be used for early stopping.
#
# Will train until valid-rmse hasn't improved in 50 rounds.
# [1000]	train-rmse:1.38643	valid-rmse:1.54772
# Stopping. Best iteration:
# [1460]	train-rmse:1.34052	valid-rmse:1.54646
#
# Fold  1 RMSE : 1.546468
# XGB 1--------------------------------------------------
# [0]	train-rmse:1.79627	valid-rmse:1.7941
# Multiple eval metrics have been passed: 'valid-rmse' will be used for early stopping.
#
# Will train until valid-rmse hasn't improved in 50 rounds.
# [1000]	train-rmse:1.3854	valid-rmse:1.55947
# Stopping. Best iteration:
# [1729]	train-rmse:1.32039	valid-rmse:1.5577
#
# Fold  2 RMSE : 1.557722
# XGB 2--------------------------------------------------
# [0]	train-rmse:1.79402	valid-rmse:1.80305
# Multiple eval metrics have been passed: 'valid-rmse' will be used for early stopping.
#
# Will train until valid-rmse hasn't improved in 50 rounds.
# [1000]	train-rmse:1.38442	valid-rmse:1.56482
# Stopping. Best iteration:
# [1525]	train-rmse:1.33469	valid-rmse:1.56339
#
# Fold  3 RMSE : 1.563396
# XGB 3--------------------------------------------------
# [0]	train-rmse:1.7924	valid-rmse:1.80948
# Multiple eval metrics have been passed: 'valid-rmse' will be used for early stopping.
#
# Will train until valid-rmse hasn't improved in 50 rounds.
# [1000]	train-rmse:1.38254	valid-rmse:1.5692
# Stopping. Best iteration:
# [1562]	train-rmse:1.32912	valid-rmse:1.56774
#
# Fold  4 RMSE : 1.567769
# XGB 4--------------------------------------------------
# [0]	train-rmse:1.79586	valid-rmse:1.79575
# Multiple eval metrics have been passed: 'valid-rmse' will be used for early stopping.
#
# Will train until valid-rmse hasn't improved in 50 rounds.
# [1000]	train-rmse:1.3857	valid-rmse:1.55848
# Stopping. Best iteration:
# [1751]	train-rmse:1.31886	valid-rmse:1.55614
#
# Fold  5 RMSE : 1.556172
# 1.558322182992426
# Wall time: 9h 14min 13s

# %%
from scipy.optimize import minimize

def find_best_weight(preds, target):
    def _validate_func(weights):
        ''' scipy minimize will pass the weights as a numpy array '''
        final_prediction = 0
        for weight, prediction in zip(weights, preds):
                final_prediction += weight * prediction
        return np.sqrt(mean_squared_error(final_prediction, target))

    #the algorithms need a starting value, right not we chose 0.5 for all weights
    #its better to choose many random starting points and run minimize a few times
    starting_values = [0.5]*len(preds)

    #adding constraints and a different solver as suggested by user 16universe
    #https://kaggle2.blob.core.windows.net/forum-message-attachments/75655/2393/otto%20model%20weights.pdf?sv=2012-02-12&se=2015-05-03T21%3A22%3A17Z&sr=b&sp=r&sig=rkeA7EJC%2BiQ%2FJ%2BcMpcA4lYQLFh6ubNqs2XAkGtFsAv0%3D
    cons = ({'type':'eq','fun':lambda w: 1-sum(w)})
    #our weights are bound between 0 and 1
    bounds = [(0, 1)] * len(preds)
    
    res = minimize(_validate_func, starting_values, method='Nelder-Mead', bounds=bounds, constraints=cons)
    
    print('Ensemble Score: {best_score}'.format(best_score=(1-res['fun'])))
    print('Best Weights: {weights}'.format(weights=res['x']))
    
    return res

# %%
res = find_best_weight([oof_lgb, oof_cb, oof_xgb], target)
# Out:
# D:\Soft\Anaconda3\envs\env_keras\lib\site-packages\scipy\optimize\_minimize.py:518: RuntimeWarning: Method Nelder-Mead cannot handle constraints nor bounds.
#   RuntimeWarning)
# Ensemble Score: -0.55650325720128
# Best Weights: [0.36024638 0.31976519 0.35192096]

# %%
model_without_outliers = pd.DataFrame({"card_id":df_test["card_id"].values})
model_without_outliers["target"] = 0.36024638*predictions_lgb + 0.31976519*predictions_cb + 0.35192096*predictions_xgb

# %%
# simple model
model_without_outliers = pd.DataFrame({"card_id":df_test["card_id"].values})
model_without_outliers["target"] = predictions_lgb

# %% [markdown]
# ## Step 2. Predicting outliers

# %%
# %%time
df_train = pd.read_csv('D:\Ellunium\elo/train_data_clean_16_02.csv')
df_test = pd.read_csv('D:\Ellunium\elo/test_data_clean_16_02.csv')
# Out:
# Wall time: 26.3 s

# %%
target = df_train['outliers']
del df_train['outliers']
del df_train['target']

# %%
param = {'num_leaves': 31,
         'min_data_in_leaf': 30, 
         'objective':'binary',
         'max_depth': 6,
         'learning_rate': 0.01,
         "boosting": "rf",
         "feature_fraction": 0.9,
         "bagging_freq": 1,
         "bagging_fraction": 0.9 ,
         "bagging_seed": 11,
         "metric": 'binary_logloss',
         "lambda_l1": 0.1,
         "verbosity": -1,
         "random_state": 2333}

# %%
# %%time
folds = KFold(n_splits=5, shuffle=True, random_state=15)
oof = np.zeros(len(df_train))
predictions = np.zeros(len(df_test))
feature_importance_df = pd.DataFrame()

start = time.time()


for fold_, (trn_idx, val_idx) in enumerate(folds.split(df_train.values, target.values)):
    print("fold n°{}".format(fold_))
    trn_data = lgb.Dataset(df_train.iloc[trn_idx][features], label=target.iloc[trn_idx], categorical_feature=categorical_feats)
    val_data = lgb.Dataset(df_train.iloc[val_idx][features], label=target.iloc[val_idx], categorical_feature=categorical_feats)

    num_round = 10000
    clf = lgb.train(param, trn_data, num_round, valid_sets = [trn_data, val_data], verbose_eval=100, early_stopping_rounds = 200)
    oof[val_idx] = clf.predict(df_train.iloc[val_idx][features], num_iteration=clf.best_iteration)
    
    fold_importance_df = pd.DataFrame()
    fold_importance_df["feature"] = features
    fold_importance_df["importance"] = clf.feature_importance()
    fold_importance_df["fold"] = fold_ + 1
    feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
    
    predictions += clf.predict(df_test[features], num_iteration=clf.best_iteration) / folds.n_splits

print("CV score: {:<8.5f}".format(log_loss(target, oof)))
# Out:
# fold n°0
# D:\Soft\Anaconda3\envs\env_keras\lib\site-packages\lightgbm\basic.py:1184: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# D:\Soft\Anaconda3\envs\env_keras\lib\site-packages\lightgbm\basic.py:742: UserWarning: categorical_feature in param dict is overridden.
#   warnings.warn('categorical_feature in param dict is overridden.')
# Training until validation scores don't improve for 200 rounds.
# [100]	training's binary_logloss: 0.0439813	valid_1's binary_logloss: 0.0469813
# [200]	training's binary_logloss: 0.0440024	valid_1's binary_logloss: 0.0470181
# Early stopping, best iteration is:
# [63]	training's binary_logloss: 0.0439481	valid_1's binary_logloss: 0.0469078
# fold n°1
# Training until validation scores don't improve for 200 rounds.
# [100]	training's binary_logloss: 0.0442106	valid_1's binary_logloss: 0.0453628
# [200]	training's binary_logloss: 0.0441944	valid_1's binary_logloss: 0.0453443
# Early stopping, best iteration is:
# [65]	training's binary_logloss: 0.0442016	valid_1's binary_logloss: 0.0452901
# fold n°2
# Training until validation scores don't improve for 200 rounds.
# [100]	training's binary_logloss: 0.0444285	valid_1's binary_logloss: 0.0438536
# [200]	training's binary_logloss: 0.0444377	valid_1's binary_logloss: 0.0438545
# Early stopping, best iteration is:
# [49]	training's binary_logloss: 0.0444558	valid_1's binary_logloss: 0.0437817
# fold n°3
# Training until validation scores don't improve for 200 rounds.
# [100]	training's binary_logloss: 0.0431045	valid_1's binary_logloss: 0.0498586
# [200]	training's binary_logloss: 0.0431084	valid_1's binary_logloss: 0.049889
# [300]	training's binary_logloss: 0.0430952	valid_1's binary_logloss: 0.0498986
# Early stopping, best iteration is:
# [101]	training's binary_logloss: 0.0431028	valid_1's binary_logloss: 0.0498559
# fold n°4
# Training until validation scores don't improve for 200 rounds.
# [100]	training's binary_logloss: 0.0443791	valid_1's binary_logloss: 0.0452893
# [200]	training's binary_logloss: 0.0443798	valid_1's binary_logloss: 0.0453101
# Early stopping, best iteration is:
# [65]	training's binary_logloss: 0.0443318	valid_1's binary_logloss: 0.0452471
# CV score: 0.04622
# Wall time: 8min 57s

# %%
df_outlier_prob = pd.DataFrame({"card_id":df_test["card_id"].values})
df_outlier_prob["target"] = predictions
df_outlier_prob.head()
# Out:
#            card_id    target
# 0  C_ID_0ab67a22ab  0.078945
# 1  C_ID_130fd0cbdd  0.001863
# 2  C_ID_b709037bc5  0.008478
# 3  C_ID_d27d835a9f  0.001863
# 4  C_ID_2b5e3df5c2  0.001878

# %% [markdown]
# ## Step 3. Combining submissions

# %%
# In case missing some predictable outlier, we choose top 25000 with highest outliers likelyhood.
outlier_id = pd.DataFrame(df_outlier_prob.sort_values(by='target',ascending = False).head(25000)['card_id'])

# %%
best_submission = pd.read_csv('D:\Ellunium\elo/submission_elo_strat_lgb_3_64489.csv')

# %%
most_likely_liers = best_submission.merge(outlier_id,how='right')
most_likely_liers.head()
# Out:
#            card_id    target
# 0  C_ID_0ab67a22ab -2.935556
# 1  C_ID_f7cada36d3  0.431253
# 2  C_ID_6d8dba8475 -0.735170
# 3  C_ID_7f1041e8e1 -6.152643
# 4  C_ID_22e4a47c72 -0.620218

# %%
# %%time
for card_id in most_likely_liers['card_id']:
    model_without_outliers.loc[model_without_outliers['card_id']==card_id,'target']\
    = most_likely_liers.loc[most_likely_liers['card_id']==card_id,'target'].values
# Out:
# Wall time: 15min 41s

# %%
model_without_outliers.to_csv("combining_submission_lgb1702.csv", index=False)
